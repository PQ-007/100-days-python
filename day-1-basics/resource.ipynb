# %% [markdown]
# # Day 1 — Band Name Generator

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
name = input("What is your name? ")
print("Hello, " + name + "!")
# Out:
# Hello, !

# %%
# хувсагчийн утгыг солих жишээ
glass1 = "milk"
glass2 = "juice"
t = glass1
glass1 = glass2
glass2 = t
print(glass1, glass2)
# Дараа нь уншаад ойлгохоор нэр хувьсагчдаа өгч байгаарай
# Out:
# juice milk
