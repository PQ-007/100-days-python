# %%
colors = {
    "red": "\033[31m",
    "green": "\033[32m",
    "yellow": "\033[33m",
    "blue": "\033[34m",
    "magenta": "\033[35m",
    "cyan": "\033[36m",
    "reset": "\033[0m"
}
print(f"{colors['red']}This text is red.{colors['reset']}")
print(f"{colors['green']}This text is green.{colors['reset']}")
print(f"{colors['yellow']}This text is yellow.{colors['reset']}")
print(f"{colors['blue']}This text is blue.{colors['reset']}")
print(f"{colors['magenta']}This text is magenta.{colors['reset']}")
print(f"{colors['cyan']}This text is cyan.{colors['reset']}")

colors["white"] = "\033[37m"
print(f"{colors['white']}This text is white.{colors['reset']}")

empty_dict = {}
print(empty_dict)

# wiped
# colors = {}

for color in colors:
    print(color)
    print(colors[color])
# Out:
# This text is red.
# This text is green.
# This text is yellow.
# This text is blue.
# This text is magenta.
# This text is cyan.
# This text is white.
# {}
# red
#
# green
#
# yellow
#
# blue
#
# magenta
#
# cyan
#
# reset
#
# white
