# %%
import my_module
print(my_module.pi)
# Out:
# 3.14159

# %%
import random
random_integer = random.randint(1, 10)
print(random_integer)
random_float_0_to_1 = random.random()
print(random_float_0_to_1)
random_float_0_to_5 = random.random() * 5
print(random_float_0_to_5)

random_float = random.uniform(1, 10)
print(random_float)
# Out:
# 9
# 0.03530825506015223
# 1.1288021242869561
# 6.035148896890375

# %%
import random
random_integer = random.randint(0, 1)
if random_integer == 1: print("Heads")
else:    print("Tails")

# %%
list_of_names = ["Alice", "Bob", "Charlie", "David", "Ava"]
random_name = random.choice(list_of_names)
print(random_name)

list_of_ages = [25, 30, 35, 40, 1]
random_age = random.choice(list_of_ages)
print(random_age)

sorted_list_of_names = sorted(list_of_names)
sorted_list_of_ages = sorted(list_of_ages)
print(sorted_list_of_names)
print(sorted_list_of_ages)
# Out:
# Bob
# 30
# ['Alice', 'Ava', 'Bob', 'Charlie', 'David']
# [1, 25, 30, 35, 40]

# %%
friends = ["Alice", "Bob", "Charlie", "David", "Ava"]
random_friend = random.choice(friends)
print(random_friend)
# Out:
# Charlie

# %%
states_of_america = ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"]
# print(states_of_america[50])

fruits = ["Apple", "Banana", "Cherry", "Date", "Elderberry", "Fig", "Grape", "Honeydew", "Kiwi", "Lemon", "Mango", "Nectarine"]
vegetables = ["Asparagus", "Broccoli", "Carrot", "Daikon", "Eggplant", "Fennel", "Garlic", "Horseradish", "Iceberg Lettuce", "Jicama", "Kale", "Leek"]

dirty_dozen = [fruits, vegetables]
print(dirty_dozen[0][1])
print(dirty_dozen[1][2])
print(dirty_dozen)
# Out:
# Banana
# Carrot
# [['Apple', 'Banana', 'Cherry', 'Date', 'Elderberry', 'Fig', 'Grape', 'Honeydew', 'Kiwi', 'Lemon', 'Mango', 'Nectarine'], ['Asparagus', 'Broccoli', 'Carrot', 'Daikon', 'Eggplant', 'Fennel', 'Garlic', 'Horseradish', 'Iceberg Lettuce', 'Jicama', 'Kale', 'Leek']]
